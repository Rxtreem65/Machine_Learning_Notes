# %% [markdown]
# # Pie plot

# %%
# required importings
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# We will plot the number speakers of the different languages in a group.

# %%
fig = plt.figure()

# defining the axes
ax = fig.add_axes([0,0,1,1])

ax.axis('equal')

langs = ['Manderin', 'Spanish', 'French', 'Hindi', 'English']
people = [22,37,35,27,145]

# defining the plot
ax.pie(students, labels = langs,autopct='%1.2f%%')

# draw the plot
plt.show()
